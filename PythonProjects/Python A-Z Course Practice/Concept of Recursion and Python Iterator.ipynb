# %% [markdown]
# # Python Recursion
#
# Recursive functions make the code look clean and elegant.
# A complex task can be broken down into simpler sub-problems using recursion.

# %% [markdown]
# factorial(3)          # 1st call with 3
# 3 * factorial(2)      # 2nd call with 2
# 3 * 2 * factorial(1)  # 3rd call with 1
# 3 * 2 * 1             # return from 3rd call as number=1
# 3 * 2                 # return from 2nd call
# 6                     # return from 1st call

# %% [markdown]
# ![python-factorial-function.png](attachment:python-factorial-function.png)

# %% [markdown]
# # An iterator in Python programming language is an object which you can iterate upon. That is, it returns one object at a time.
#
# Python Iterator, implicitly implemented in constructs like for-loops
#
# The iter() and next() functions collectively form the iterator protocol

# %%
evens=[2,4,6,8,10]
for x in evens:
  print(x)

# %%
evens=[2,4,6,8,10]

# %%
evenIterator=iter(evens)

# %%
next(evenIterator)

# %%
next(evenIterator)

# %%
next(evenIterator)

# %%
nums=[1,2,3]

# %%
numIter=iter(nums)

# %%
numIter.__next__()

# %%
numIter.__next__()

# %%
numIter.__next__()

# %%
name='python'
for x in name:
    print(x)

# %%
iter_obj=iter('Python')
while True:
    try:
        i=next(iter_obj)
        print(i)
    except StopIteration:
        break
