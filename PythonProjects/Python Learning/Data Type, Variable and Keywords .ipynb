# %% [markdown]
# # Vaiable :- Variables are nothing but reserved memory locations to store values

# %% [markdown]
# # Data Type

# %% [markdown]
# # Integer

# %%
a=4

# %%
a

# %%
type(a)

# %% [markdown]
# # Float

# %%
b=5.6

# %%
print(b)

# %%
type(b)

# %% [markdown]
# # String

# %%
x='M'

# %%
x

# %%
type(x)

# %%
y="MHM"

# %%
type(y)

# %% [markdown]
# ## convertions

# %%
x=6

# %%
type(x)

# %%
float(x)

# %%
str(x)

# %% [markdown]
# # Boolean

# %%
x= True

# %%
bool(x)

# %%
y= False

# %%
bool(y)

# %% [markdown]
# # Complex

# %%
x= 4+5j

# %%
type(x)

# %% [markdown]
# # KeyWord :- Keywords are the reserved words in Python. It cannot use as a variable name, function name or any other identifier.

# %% [markdown]
# ![Python%20PPT%20final.jpg](attachment:Python%20PPT%20final.jpg)

# %%
as=4

# %%
import keyword

# %%
keyword.iskeyword('None')

# %%
keyword.iskeyword('none')
