# %%
phonebook = {"Ram" : 956565656, "mick" : 9388658686,"Jill" : 767676767}
phonebook
# Out:
# {'Jill': 767676767, 'Ram': 956565656, 'mick': 9388658686}

# %%
phonebook1 = {}
phonebook1["John"] = 938477566
phonebook1["Jack"] = 938377264
phonebook1["Jill"] = 947662781
phonebook1
# Out:
# {'Jack': 938377264, 'Jill': 947662781, 'John': 938477566}

# %%
"Ram" in phonebook
# Out:
# True

# %%
956565656 in phonebook
# Out:
# False

# %%
len(phonebook)
# Out:
# 3

# %%
type(phonebook)
# Out:
# dict

# %%
dict = {'Name': 'Rama', 'Age': 7, 'Class': 'First'}

# %%
dict.keys()
# Out:
# dict_keys(['Name', 'Age', 'Class'])

# %%
dict.values()
# Out:
# dict_values(['Rama', 7, 'First'])

# %%
dict.items()
# Out:
# dict_items([('Name', 'Rama'), ('Age', 7), ('Class', 'First')])

# %%
del dict['Name']

# %%
dict
# Out:
# {'Age': 7, 'Class': 'First'}

# %%
dict.clear()

# %%
dict
# Out:
# {}
