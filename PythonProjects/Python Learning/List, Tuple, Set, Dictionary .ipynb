# %% [markdown]
# ![Python%20PPT%20final.jpg](attachment:Python%20PPT%20final.jpg)

# %% [markdown]
# # Tuple

# %%
a= (1,2,3,4)

# %%
type(a)

# %%
a=1,2,3,4

# %%
type(a)

# %%
a=(1)

# %%
type(a)

# %%
a=(1,)

# %%
type(a)

# %%
a=1

# %%
type(a)

# %%
a=1,

# %%
type(a)

# %% [markdown]
# # List

# %%
a= [1,2,3,4]

# %%
type(a)

# %% [markdown]
# # Set

# %%
a= {1,2,3,4,4,4,4,3}
a

# %%
type(a)

# %% [markdown]
# # Dictionary

# %%
a={1:2,2:3}

# %%
type(a)

# %%
a[1]
